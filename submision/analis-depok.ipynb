# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("depok.xlsx")
data
# Out:
#         Tanggal    Jam  Tinggi Air
# 0    2023-01-01  00:00        1350
# 1    2023-01-01  00:10           0
# 2    2023-01-01  00:20        1350
# 3    2023-01-01  00:30        1350
# 4    2023-01-01  00:40        1340
# ...         ...    ...         ...
# 4423 2023-01-31  23:10         910
# 4424 2023-01-31  23:20         910
# 4425 2023-01-31  23:30         920
# 4426 2023-01-31  23:40         920
# 4427 2023-01-31  23:50         930
#
# [4428 rows x 3 columns]

# %%
data.head()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4428 entries, 0 to 4427
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     4428 non-null   datetime64[ns]
#  1   Jam         4428 non-null   object
#  2   Tinggi Air  4428 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 103.9+ KB
#                              Tanggal   Tinggi Air
# count                           4428  4428.000000
# mean   2023-01-16 00:14:38.048780544  1022.235772
# min              2023-01-01 00:00:00     0.000000
# 25%              2023-01-08 00:00:00   920.000000
# 50%              2023-01-16 00:00:00   980.000000
# 75%              2023-01-24 00:00:00  1082.500000
# max              2023-01-31 00:00:00  1620.000000
# std                              NaN   137.600583

# %%
plt.figure(figsize=(25, 25))
plt.plot(data['Jam'], data['Tinggi Air'])
plt.xlabel('Jam')
plt.ylabel('Tinggi Air')
plt.title('Grafik Tinggi Air')
plt.grid(True)
plt.show()

# %%
# Misalnya, jika Anda sudah memiliki data dalam DataFrame 'data'
plt.figure(figsize=(10,5))
sns.boxplot(x='Tanggal', y='Tinggi Air', data=data)
plt.xlabel('Tanggal')
plt.ylabel('Tinggi Air')
plt.title('Boxplot Tinggi Air per Tanggal')
plt.xticks(rotation=45)
plt.show()
