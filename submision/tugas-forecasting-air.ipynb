# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
data = pd.read_csv('marina_complete.csv')

# %%
pd.DataFrame(data)
# Out:
#                          ds      y
# 0      2021-01-01T00:00:00Z  170.0
# 1      2021-01-01T01:00:00Z  161.0
# 2      2021-01-01T02:00:00Z  172.0
# 3      2021-01-01T03:00:00Z  177.0
# 4      2021-01-01T04:00:00Z  181.0
# ...                     ...    ...
# 21140  2023-05-31T20:00:00Z  213.0
# 21141  2023-05-31T21:00:00Z  214.0
# 21142  2023-05-31T22:00:00Z  212.0
# 21143  2023-05-31T23:00:00Z  208.0
# 21144  2023-06-01T00:00:00Z  203.0
#
# [21145 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['y'], label='Kenaikan Air (cm)')
plt.title('Time Series Data Kenaikan Air')
plt.xlabel('Tanggal')
plt.ylabel('Kenaikan Air (cm)')
plt.legend()
plt.show()

# %%
model = ExponentialSmoothing(data['y'], trend='add', seasonal='add', seasonal_periods=24)
model_fit = model.fit()
model_fit

# %%
forecast_steps = 6
forecast = model_fit.forecast(steps=forecast_steps)
print(f'Hasil Prediksi 6 Jam ke Depan: {forecast}')
# Out:
# Hasil Prediksi 6 Jam ke Depan: 21145    196.455749
# 21146    188.709273
# 21147    182.187471
# 21148    177.134870
# 21149    171.462116
# 21150    166.738118
# dtype: float64
